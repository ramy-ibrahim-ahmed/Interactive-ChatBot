# %%
# !pip install redis
import redis

r = redis.Redis(host="10.0.0.5", port=6379, password=None)  # add password if enabled
r.set("testkey", "hello")
print(r.get("testkey"))
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\ramyu\AppData\Local\Programs\Python\Python313\Lib\site-packages\redis\connection.py:855, in AbstractConnection.connect_check_health(self, check_health, retry_socket_connect)
#     854 if retry_socket_connect:
# --> 855     sock = self.retry.call_with_retry(
#     856         lambda: self._connect(), lambda error: self.disconnect(error)
#     857     )
#     858 else:
#
# File c:\Users\ramyu\AppData\Local\Programs\Python\Python313\Lib\site-packages\redis\retry.py:116, in Retry.call_with_retry(self, do, fail, is_retryable)
#     115 try:
# --> 116     return do()
#     117 except self._supported_errors as error:
#
# ...
