# %%
systems = {
    "restaurant": "يهدف نظام إدارة المطاعم إلى تنظيم جميع العمليات داخل المطعم بشكل متكامل، بدءًا من استلام الطلبات وحتى إدارة المخزون والمحاسبة. يتيح النظام تتبع الطلبات في الوقت الفعلي، وإدارة قوائم الطعام، ومراقبة المخزون من المكونات الغذائية لتفادي الهدر. كما يوفر لوحة تحكم للإدارة لمتابعة الأداء المالي، والمبيعات اليومية، وكفاءة الموظفين. يدعم النظام التكامل مع أنظمة نقاط البيع (POS) وخدمات التوصيل عبر الإنترنت لتوفير تجربة تشغيل سلسة وشاملة.",
    "sales": "يركز نظام إدارة المبيعات على تحسين دورة المبيعات بالكامل من لحظة تسجيل العميل المحتمل وحتى إتمام الصفقة والفوترة. يساعد في تتبع أداء مندوبي المبيعات، وإدارة الحملات التسويقية، وتحليل بيانات السوق لتحديد الفرص الجديدة. كما يتيح إعداد تقارير دقيقة عن الأرباح، والمبيعات الشهرية، والمنتجات الأكثر طلبًا. يمكن دمجه مع أنظمة إدارة العملاء والمخزون لضمان تدفق متكامل للبيانات بين الأقسام المختلفة.",
    "customers": "يهدف نظام إدارة العملاء إلى بناء علاقات قوية ومستدامة مع العملاء من خلال إدارة بياناتهم وسلوكهم الشرائي وتاريخ تعاملاتهم. يوفر أدوات لتحليل رضا العملاء، وتتبع التواصل معهم عبر قنوات متعددة مثل البريد الإلكتروني، الهاتف، أو وسائل التواصل الاجتماعي. يساعد النظام فرق المبيعات وخدمة العملاء على تخصيص العروض وتحسين تجربة العميل. كما يتيح إنشاء تقارير ذكية تساعد الإدارة في اتخاذ قرارات استراتيجية لزيادة الولاء والاحتفاظ بالعملاء.",
    "real_estate": "يُستخدم نظام إدارة العقارات لإدارة العمليات العقارية مثل تأجير وبيع العقارات، إدارة العقود، الصيانة، والمحاسبة العقارية. يسمح بإدارة بيانات المستأجرين والملاك، وجدولة الدفعات، وتتبع العقود المنتهية أو المجددة. كما يتضمن أدوات لإدارة الصيانة الدورية، ومراقبة أداء الوحدات العقارية، وإصدار تقارير مالية دقيقة. يدعم النظام التكامل مع أنظمة الدفع الإلكتروني والمحاسبة لتسهيل العمليات المالية وتوفير رؤية شاملة عن الأداء العقاري.",
}
